# %%
#handling missing outliers vai iqr

# %%
import numpy as np
import pandas as pd

# %%
list_ = [1,2,3,4,5,6,9,10,12,55,60]

# %%
list_
# Out:
# [1, 2, 3, 4, 5, 6, 9, 10, 12, 55, 60]

# %%
Q1 = np.percentile(list_,25)

# %%
Q1
# Out:
# np.float64(3.5)

# %%
Q3 = np.percentile(list_,75)

# %%
Q3
# Out:
# np.float64(11.0)

# %%
IQR =  Q3-Q1

# %%
IQR
# Out:
# np.float64(7.5)

# %%
low = Q1 - 1.5*IQR

# %%
upper = Q3 + 1.5*IQR

# %%
outliers =[]

# %%
list_
# Out:
# [1, 2, 3, 4, 5, 6, 9, 10, 12, 55, 60]

# %%
for i in list_:
    if((i>upper)or(i>low)):
        outliers.append(i)

# %%
outliers
# Out:
# [1, 2, 3, 4, 5, 6, 9, 10, 12, 55, 60]

# %%
list_ = [i for i in list_ if i not in outliers]
list_
# Out:
# []

# %%
## DUPLICATES

# %%
data = pd.DataFrame({'team':['A','A','A','A','B','B','B','B'],
                  'points':[10,10,12,12,15,17,20,20],
                  'assists':[5,5,7,9,12,9,6,6]})

# %%
data
# Out:
#   team  points  assists
# 0    A      10        5
# 1    A      10        5
# 2    A      12        7
# 3    A      12        9
# 4    B      15       12
# 5    B      17        9
# 6    B      20        6
# 7    B      20        6

# %%
data.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
data[data.duplicated()]
# Out:
#   team  points  assists
# 1    A      10        5
# 7    B      20        6

# %%
data[data.duplicated('team')]
# Out:
#   team  points  assists
# 1    A      10        5
# 2    A      12        7
# 3    A      12        9
# 5    B      17        9
# 6    B      20        6
# 7    B      20        6

# %%
data[data.duplicated('team','points')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data[data.duplicated('team','points')]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:6976, in DataFrame.duplicated(self, subset, keep)
#    6972     raise KeyError(Index(diff))
#    6974 if len(subset) == 1 and self.columns.is_unique:
#    6975     # GH#45236 This is faster than get_group_index below
# -> 6976     result = self[subset[0]].duplicated(keep)
#    6977     result.name = None
#    6978 else:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:2616, in Series.duplicated(self, keep)
#    2540 def duplicated(self, keep: DropKeep = "first") -> Series:
#    2541     """
#    2542     Indicate duplicate Series values.
#    2543
#    (...)   2614     dtype: bool
#    2615     """
# -> 2616     res = self._duplicated(keep=keep)
#    2617     result = self._constructor(res, index=self.index, copy=False)
#    2618     return result.__finalize__(self, method="duplicated")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\base.py:1378, in IndexOpsMixin._duplicated(self, keep)
#    1376 if isinstance(arr, ExtensionArray):
#    1377     return arr.duplicated(keep=keep)
# -> 1378 return algorithms.duplicated(arr, keep=keep)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1020, in duplicated(values, keep, mask)
#     999 """
#    1000 Return boolean ndarray denoting duplicate values.
#    1001
#    (...)   1017 duplicated : ndarray[bool]
#    1018 """
#    1019 values = _ensure_data(values)
# -> 1020 return htable.duplicated(values, keep=keep, mask=mask)
#
# File pandas/_libs/hashtable_func_helper.pxi:2655, in pandas._libs.hashtable.__pyx_fuse_10duplicated()
#
# File pandas/_libs/hashtable_func_helper.pxi:2657, in pandas._libs.hashtable.duplicated()
#
# File pandas/_libs/hashtable_func_helper.pxi:1692, in pandas._libs.hashtable.duplicated_object()
#
# ValueError: keep must be either "first", "last" or False
